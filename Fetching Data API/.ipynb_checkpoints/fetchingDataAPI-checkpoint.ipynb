# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer API"
}

# %%
response = requests.get(url, headers=headers)

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#          id                      title  \
# 0    460508              Munna Michael
# 1    653664          Dinner in America
# 2    513268                   Body Cam
# 3    467956              The Professor
# 4    710692        Aunt's Temptation 3
# 5     17729     The Glenn Miller Story
# 6    271116                Devil Angel
# 7    579583  The King of Staten Island
# 8    410554                 First Kill
# 9      1485                 Get Carter
# 10   279988                 Extinction
# 11    29369              Made in U.S.A
# 12    61202   Zindagi Na Milegi Dobara
# 13   688258       Occupation: Rainfall
# 14    41343         The God of Cookery
# 15     8092            This Boy's Life
# 16      267                 Live Flesh
# 17  1009263              Lampas Langit
# 18   567690           Dear Evan Hansen
# 19   419114                  Bed-Rella
#
#                                              overview release_date  \
# 0   An expert dancer Munna who idolizes the king o...   2017-07-20
# 1   An on-the-lam punk rocker and a young woman ob...   2022-05-27
# 2   As a police officer investigates the gruesome ...   2020-05-19
# 3   A world-weary college professor is given a lif...   2018-05-17
# 4   Tae-hun, a young and sexy aunt and a nephew of...   2020-05-22
# 5   A vibrant tribute to one of America's legendar...   1954-01-04
# 6   Chi Kit worked in a stock company. One day, th...   1995-11-09
# 7   Scott has been a case of arrested development ...   2020-07-22
# 8   A police chief tries to solve a kidnapping tha...   2017-07-21
# 9   Jack Carter is a small-time hood working in Lo...   1971-02-03
# 10  Deep in the Amazon jungle a group of scientist...   2014-08-24
# 11  Paula Nelson goes to Atlantic City to meet her...   1967-01-27
# 12  Three friends who were inseparable in childhoo...   2011-07-15
# 13  Two years into an intergalactic invasion of Ea...   2020-10-30
# 14  The most renowned and feared chef in the world...   1996-12-21
# 15  When a son and mother move to Seattle in hopes...   1993-04-09
# 16  When Victor attempts to seduce Elena, all he g...   1997-10-10
# 17  An author, whose marriage is on the rocks, mee...   2022-08-19
# 18  Evan Hansen, a high schooler with social anxie...   2021-09-24
# 19  Min-cheol goes down to the countryside to focu...   2016-09-22
#
#     popularity  vote_average  vote_count
# 0       14.998         5.900          46
# 1       12.881         7.800         126
# 2       13.872         6.200         353
# 3       14.868         6.900        1160
# 4       13.351         7.300          16
# 5        9.612         6.927         150
# 6       13.631         4.300           9
# 7       14.122         7.009        1013
# 8       12.867         5.700         558
# 9       11.860         7.003         497
# 10      13.244         3.900          46
# 11      12.801         6.100          98
# 12      15.113         7.600         352
# 13      13.621         6.200         241
# 14      17.859         7.162         179
# 15      13.359         7.100         992
# 16      13.110         7.100         672
# 17      19.685         5.400           5
# 18      12.874         6.277         330
# 19       8.704         9.000           3

# %%
df.head()
df = pd.DataFrame()

# %%
for i in range (1,429):
    url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page={i}&sort_by=popularity.desc"

    
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer API"
    }
    
    response = requests.get(url, headers=headers)
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]    
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21360/3061398644.py in <module>
#       9
#      10     response = requests.get(url, headers=headers)
# ---> 11     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#      12     df = df.append(temp_df,ignore_index=True)
#
# KeyError: 'results'

# %%
df
# Out:
#            id                 title  \
# 0      939243  Sonic the Hedgehog 3
# 1      539972     Kraven the Hunter
# 2     1241982               Moana 2
# 3      993710        Back in Action
# 4     1249289                Alarum
# ...       ...                   ...
# 8555     8092       This Boy's Life
# 8556      267            Live Flesh
# 8557  1009263         Lampas Langit
# 8558   567690      Dear Evan Hansen
# 8559   419114             Bed-Rella
#
#                                                overview release_date  \
# 0     Sonic, Knuckles, and Tails reunite against a p...   2024-12-19
# 1     Kraven Kravinoff's complex relationship with h...   2024-12-11
# 2     After receiving an unexpected call from her wa...   2024-11-21
# 3     Fifteen years after vanishing from the CIA to ...   2025-01-15
# 4     Two married spies caught in the crosshairs of ...   2025-01-16
# ...                                                 ...          ...
# 8555  When a son and mother move to Seattle in hopes...   1993-04-09
# 8556  When Victor attempts to seduce Elena, all he g...   1997-10-10
# 8557  An author, whose marriage is on the rocks, mee...   2022-08-19
# 8558  Evan Hansen, a high schooler with social anxie...   2021-09-24
# 8559  Min-cheol goes down to the countryside to focu...   2016-09-22
#
#       popularity  vote_average  vote_count
# 0       3435.809         7.803        1497
# 1       2056.111         6.600        1026
# 2       1831.321         7.200        1266
# 3       1534.220         6.631         765
# 4       1392.625         5.800         110
# ...          ...           ...         ...
# 8555      13.359         7.100         992
# 8556      13.110         7.100         672
# 8557      19.685         5.400           5
# 8558      12.874         6.277         330
# 8559       8.704         9.000           3
#
# [8560 rows x 7 columns]
