# %%
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\SUJAL\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df =sns.load_dataset('tips')

# %%
df.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 139       13.16  2.75  Female     No  Thur   Lunch     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 212       48.33  9.00    Male     No   Sat  Dinner     4

# %%
titanic = pd.read_csv('train.csv')

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(df['total_bill'], df['tip'], hue=df['time'], style=df['smoker'], size=df['size'])
# Out:
# C:\Users\SUJAL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Bar Plot (Numerical - Categorical)

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 507          508         1       1
# 478          479         0       3
# 602          603         0       1
# 560          561         0       3
# 123          124         1       2
#
#                                               Name     Sex   Age  SibSp  \
# 507  Bradley, Mr. George ("George Arthur Brayton")    male   NaN      0
# 478                      Karlsson, Mr. Nils August    male  22.0      0
# 602                      Harrington, Mr. Charles H    male   NaN      0
# 560                       Morrow, Mr. Thomas Rowan    male   NaN      0
# 123                            Webber, Miss. Susan  female  32.5      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 507      0  111427  26.5500   NaN        S
# 478      0  350060   7.5208   NaN        S
# 602      0  113796  42.4000   NaN        S
# 560      0  372622   7.7500   NaN        Q
# 123      0   27267  13.0000  E101        S

# %%
sns.barplot(titanic['Pclass'], titanic['Fare'], hue=titanic['Sex'])
# Out:
# C:\Users\SUJAL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## Box Plot (Numerical - Categorical)

# %%
sns.boxplot(titanic['Sex'], titanic['Age'], hue=titanic['Survived'])
# Out:
# C:\Users\SUJAL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## Distplot (Numerical - Categorical)

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'], hist= False)

sns.distplot(titanic[titanic['Survived']==1]['Age'], hist = False)
# Out:
# C:\Users\SUJAL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\SUJAL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Heatmap (Categorical - Categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Pclass').mean()['Survived']*100).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
(titanic.groupby('Sex').mean()['Survived']*100).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sex'>

# %% [markdown]
# ## ClusterMap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(titanic['Survived'], titanic['SibSp']))

# %% [markdown]
# ## Pairplot

# %%
iris.sample(5)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 2            4.7          3.2           1.3          0.2      setosa
# 77           6.7          3.0           5.0          1.7  versicolor
# 32           5.2          4.1           1.5          0.1      setosa
# 42           4.4          3.2           1.3          0.2      setosa

# %%
sns.pairplot(iris, hue="species")

# %% [markdown]
# ## Lineplot (Numerical - Numerical)

# %%
flights.sample(5)
# Out:
#      year month  passengers
# 126  1959   Jul         548
# 11   1949   Dec         118
# 93   1956   Oct         306
# 31   1951   Aug         199
# 0    1949   Jan         112

# %%
new = flights.groupby('year').sum().reset_index()

# %%
sns.lineplot(new['year'],new['passengers'])
# Out:
# C:\Users\SUJAL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>
