# %%
import numpy as np
import pandas as pd
import pickle

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Test User Input
test_input = np.array([1, 'female', 10.0, 4, 2, 90, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input)
# Out:
# c:\users\sujal\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\users\sujal\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
